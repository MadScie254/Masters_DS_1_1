# %%
# Welcome to your new notebook
# Type here in the cell editor to add code!

# %%
# Write dataframe to Parquet file format
parquet_output_path = "Files/your_folder/your_file_name"

df.write.mode("overwrite").parquet(parquet_output_path)

print(f"DataFrame has been written to Parquet file: {parquet_output_path}")

# %%
# Azure SQL Database connection info
server_name = "your_server_name.database.windows.net"
port_number = 1433  # Default port number for SQL Server
database_name = "your_database_name"
table_name = "YourTableName" # Database table

client_id = "YOUR_CLIENT_ID"  # Service principal client ID
client_secret = "YOUR_CLIENT_SECRET"  # Service principal client secret

# Build the Azure SQL Database JDBC URL with Service Principal 
jdbc_url = f"jdbc:sqlserver://{server_name}:{port_number};database={database_name};encrypt=true;trustServerCertificate=false;hostNameInCertificate=*.database.windows.net;loginTimeout=30;Authentication=ActiveDirectoryServicePrincipal"

# Properties for the JDBC connection 
properties = {
    "user": client_id,
    "password": client_secret
            }

# Read table from Azure SQL Database using Entra ID Service Principal
sql_df = spark.read.jdbc(url=jdbc_url, table=table_name, properties=properties)

# Display the Azure SQL dataframe
display (sql_df)

# %%
# Azure Blob Storage access info
blob_account_name = "azureopendatastorage"
blob_container_name = "nyctlc"
blob_relative_path = "yellow"

# blob_sas_token = "add your SAS token here" 
# Construct the path for connection
wasbs_path = f'wasbs://{blob_container_name}@{blob_account_name}.blob.core.windows.net/{blob_relative_path}'

# WASBS path for connection including SAS token
# wasbs_path = f'wasbs://{blob_container_name}@{blob_account_name}.blob.core.windows.net/{blob_relative_path}?{blob_sas_token}'

# Read parquet data from Azure Blob Storage path
blob_df = spark.read.parquet(wasbs_path)

# Display the Azure Blob DataFrame
display(blob_df)
# Out:
# StatementMeta(, 9a23de67-4901-49c8-84e8-6277768655f7, 3, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 932d4c32-0e03-4f1a-879b-0563fa99658c)

# %%
blob_df.head(100)
# Out:
# StatementMeta(, 9a23de67-4901-49c8-84e8-6277768655f7, 8, Finished, Available, Finished)
# [Row(vendorID='CMT', tpepPickupDateTime=datetime.datetime(2012, 2, 29, 23, 53, 14), tpepDropoffDateTime=datetime.datetime(2012, 3, 1, 0, 0, 43), passengerCount=1, tripDistance=2.1, puLocationId=None, doLocationId=None, startLon=-73.980494, startLat=40.730601, endLon=-73.983532, endLat=40.752311, rateCodeId=1, storeAndFwdFlag='N', paymentType='CSH', fareAmount=7.3, extra=0.5, mtaTax=0.5, improvementSurcharge=None, tipAmount=0.0, tollsAmount=0.0, totalAmount=8.3, puYear=2012, puMonth=3),
#  Row(vendorID='VTS', tpepPickupDateTime=datetime.datetime(2012, 3, 17, 8, 1), tpepDropoffDateTime=datetime.datetime(2012, 3, 17, 8, 15), passengerCount=1, tripDistance=11.06, puLocationId=None, doLocationId=None, startLon=-73.986067, startLat=40.699862, endLon=-73.814838, endLat=40.737052, rateCodeId=1, storeAndFwdFlag=None, paymentType='CRD', fareAmount=24.5, extra=0.0, mtaTax=0.5, improvementSurcharge=None, tipAmount=4.9, tollsAmount=0.0, totalAmount=29.9, puYear=2012, puMonth=3),
#  Row(vendorID='CMT', tpepPickupDateTime=datetime.datetime(2012, 2, 29, 23, 58, 51), tpepDropoffDateTime=datetime.datetime(2012, 3, 1, 0, 15, 48), passengerCount=1, tripDistance=3.4, puLocationId=None, doLocationId=None, startLon=-73.968967, startLat=40.754359, endLon=-73.957048, endLat=40.743289, rateCodeId=1, storeAndFwdFlag='N', paymentType='CRD', fareAmount=12.5, extra=0.5, mtaTax=0.5, improvementSurcharge=None, tipAmount=1.5, tollsAmount=0.0, totalAmount=15.0, puYear=2012, puMonth=3),
#  Row(vendorID='CMT', tpepPickupDateTime=datetime.datetime(2012, 3, 1, 19, 24, 16), tpepDropoffDateTime=datetime.datetime(2012, 3, 1, 19, 31, 22), passengerCount=1, tripDistance=1.3, puLocationId=None, doLocationId=None, startLon=-73.99374, startLat=40.75307, endLon=-74.005428, endLat=40.741118, rateCodeId=1, storeAndFwdFlag='N', paymentType='CRD', fareAmount=6.1, extra=1.0, mtaTax=0.5, improvementSurcharge=None, tipAmount=0.0, tollsAmount=0.0, totalAmount=7.6, puYear=2012, puMonth=3),
#  Row(vendorID='CMT', tpepPickupDateTime=datetime.datetime(2012, 2, 29, 23, 46, 32), tpepDropoffDateTime=datetime.datetime(2012, 3, 1, 0, 5, 18), passengerCount=3, tripDistance=2.0, puLocationId=None, doLocationId=None, startLon=-73.973723, startLat=40.752323, endLon=-73.948275, endLat=40.769413, rateCodeId=1, storeAndFwdFlag='N', paymentType='CSH', fareAmount=11.7, extra=0.5, mtaTax=0.5, improvementSurcharge=None, tipAmount=0.0, tollsAmount=0.0, totalAmount=12.7, puYear=2012, puMonth=3),
#  Row(vendorID='VTS', tpepPickupDateTime=datetime.datetime(2012, 3, 7, 15, 17), tpepDropoffDateTime=datetime.datetime(2012, 3, 7, 15, 26), passengerCount=5, tripDistance=1.87, puLocationId=None, doLocationId=None, startLon=-73.988237, startLat=40.75929, endLon=-73.97114, endLat=40.78275, rateCodeId=1, storeAndFwdFlag=None, paymentType='CSH', fareAmount=7.7, extra=0.0, mtaTax=0.5, improvementSurcharge=None, tipAmount=0.0, tollsAmount=0.0, totalAmount=8.2, puYear=2012, puMonth=3),
#  Row(vendorID='CMT', tpepPickupDateTime=datetime.datetime(2012, 2, 29, 23, 41, 58), tpepDropoffDateTime=datetime.datetime(2012, 3, 1, 0, 2, 29), passengerCount=1, tripDistance=12.4, puLocationId=None, doLocationId=None, startLon=-73.954536, startLat=40.727742, endLon=-73.768994, endLat=40.760246, rateCodeId=1, storeAndFwdFlag='N', paymentType='CSH', fareAmount=28.5, extra=0.5, mtaTax=0.5, improvementSurcharge=None, tipAmount=0.0, tollsAmount=0.0, totalAmount=29.5, puYear=2012, puMonth=3),
#  Row(vendorID='VTS', tpepPickupDateTime=datetime.datetime(2012, 3, 18, 15, 21), tpepDropoffDateTime=datetime.datetime(2012, 3, 18, 15, 32), passengerCount=6, tripDistance=2.51, puLocationId=None, doLocationId=None, startLon=-74.001705, startLat=40.732345, endLon=-73.974888, endLat=40.750835, rateCodeId=1, storeAndFwdFlag=None, paymentType='CSH', fareAmount=8.9, extra=0.0, mtaTax=0.5, improvementSurcharge=None, tipAmount=0.0, tollsAmount=0.0, totalAmount=9.4, puYear=2012, puMonth=3),
#  Row(vendorID='CMT', tpepPickupDateTime=datetime.datetime(2012, 2, 29, 23, 47, 8), tpepDropoffDateTime=datetime.datetime(2012, 3, 1, 0, 6, 42), passengerCount=4, tripDistance=6.3, puLocationId=None, doLocationId=None, startLon=-73.992319, startLat=40.724503, endLon=-73.923589, endLat=40.76113, rateCodeId=1, storeAndFwdFlag='N', paymentType='CRD', fareAmount=16.5, extra=0.5, mtaTax=0.5, improvementSurcharge=None, tipAmount=4.37, tollsAmount=0.0, totalAmount=21.87, puYear=2012, puMonth=3),
#  Row(vendorID='VTS', tpepPickupDateTime=datetime.datetime(2012, 3, 13, 22, 26), tpepDropoffDateTime=datetime.datetime(2012, 3, 13, 22, 37), passengerCount=1, tripDistance=1.34, puLocationId=None, doLocationId=None, startLon=-74.009907, startLat=40.706292, endLon=-74.000512, endLat=40.71733, rateCodeId=1, storeAndFwdFlag=None, paymentType='CSH', fareAmount=7.3, extra=0.5, mtaTax=0.5, improvementSurcharge=None, tipAmount=0.0, tollsAmount=0.0, totalAmount=8.3, puYear=2012, puMonth=3),
#  Row(vendorID='CMT', tpepPickupDateTime=datetime.datetime(2012, 2, 29, 23, 37, 18), tpepDropoffDateTime=datetime.datetime(2012, 3, 1, 0, 5, 52), passengerCount=1, tripDistance=8.6, puLocationId=None, doLocationId=None, startLon=-73.951277, startLat=40.794087, endLon=-73.968643, endLat=40.6923, rateCodeId=1, storeAndFwdFlag='N', paymentType='CRD', fareAmount=22.9, extra=0.5, mtaTax=0.5, improvementSurcharge=None, tipAmount=4.75, tollsAmount=0.0, totalAmount=28.65, puYear=2012, puMonth=3),
#  Row(vendorID='VTS', tpepPickupDateTime=datetime.datetime(2012, 3, 8, 15, 18), tpepDropoffDateTime=datetime.datetime(2012, 3, 8, 15, 33), passengerCount=2, tripDistance=3.24, puLocationId=None, doLocationId=None, startLon=-73.954052, startLat=40.78458, endLon=-73.96647, endLat=40.753827, rateCodeId=1, storeAndFwdFlag=None, paymentType='CRD', fareAmount=11.3, extra=0.0, mtaTax=0.5, improvementSurcharge=None, tipAmount=1.0, tollsAmount=0.0, totalAmount=12.8, puYear=2012, puMonth=3),
#  Row(vendorID='CMT', tpepPickupDateTime=datetime.datetime(2012, 2, 29, 23, 44, 35), tpepDropoffDateTime=datetime.datetime(2012, 3, 1, 0, 10, 21), passengerCount=1, tripDistance=13.7, puLocationId=None, doLocationId=None, startLon=-73.955789, startLat=40.764043, endLon=-73.97224, endLat=40.61671, rateCodeId=1, storeAndFwdFlag='N', paymentType='CSH', fareAmount=31.7, extra=0.5, mtaTax=0.5, improvementSurcharge=None, tipAmount=0.0, tollsAmount=4.8, totalAmount=37.5, puYear=2012, puMonth=3),
#  Row(vendorID='VTS', tpepPickupDateTime=datetime.datetime(2012, 3, 2, 12, 17), tpepDropoffDateTime=datetime.datetime(2012, 3, 2, 12, 36), passengerCount=1, tripDistance=3.62, puLocationId=None, doLocationId=None, startLon=-74.001298, startLat=40.741312, endLon=-73.963897, endLat=40.773907, rateCodeId=1, storeAndFwdFlag=None, paymentType='CSH', fareAmount=12.9, extra=0.0, mtaTax=0.5, improvementSurcharge=None, tipAmount=0.0, tollsAmount=0.0, totalAmount=13.4, puYear=2012, puMonth=3),
#  Row(vendorID='CMT', tpepPickupDateTime=datetime.datetime(2012, 2, 29, 23, 45, 12), tpepDropoffDateTime=datetime.datetime(2012, 3, 1, 0, 0, 3), passengerCount=1, tripDistance=3.6, puLocationId=None, doLocationId=None, startLon=-73.974517, startLat=40.759867, endLon=-74.008417, endLat=40.725299, rateCodeId=1, storeAndFwdFlag='N', paymentType='CRD', fareAmount=11.7, extra=0.5, mtaTax=0.5, improvementSurcharge=None, tipAmount=2.54, tollsAmount=0.0, totalAmount=15.24, puYear=2012, puMonth=3),
#  Row(vendorID='VTS', tpepPickupDateTime=datetime.datetime(2012, 3, 2, 13, 4), tpepDropoffDateTime=datetime.datetime(2012, 3, 2, 13, 11), passengerCount=1, tripDistance=0.57, puLocationId=None, doLocationId=None, startLon=-73.988402, startLat=40.748175, endLon=-73.990775, endLat=40.741998, rateCodeId=1, storeAndFwdFlag=None, paymentType='CRD', fareAmount=4.9, extra=0.0, mtaTax=0.5, improvementSurcharge=None, tipAmount=1.22, tollsAmount=0.0, totalAmount=6.62, puYear=2012, puMonth=3),
#  Row(vendorID='VTS', tpepPickupDateTime=datetime.datetime(2012, 2, 29, 23, 55), tpepDropoffDateTime=datetime.datetime(2012, 3, 1, 0, 8), passengerCount=5, tripDistance=2.6, puLocationId=None, doLocationId=None, startLon=-73.981513, startLat=40.724653, endLon=-73.990597, endLat=40.750025, rateCodeId=1, storeAndFwdFlag=None, paymentType='CSH', fareAmount=10.1, extra=0.5, mtaTax=0.5, improvementSurcharge=None, tipAmount=0.0, tollsAmount=0.0, totalAmount=11.1, puYear=2012, puMonth=3),
#  Row(vendorID='VTS', tpepPickupDateTime=datetime.datetime(2012, 3, 5, 7, 11), tpepDropoffDateTime=datetime.datetime(2012, 3, 5, 7, 15), passengerCount=2, tripDistance=1.27, puLocationId=None, doLocationId=None, startLon=-73.99096, startLat=40.745807, endLon=-73.9932, endLat=40.758693, rateCodeId=1, storeAndFwdFlag=None, paymentType='CRD', fareAmount=4.9, extra=0.0, mtaTax=0.5, improvementSurcharge=None, tipAmount=1.0, tollsAmount=0.0, totalAmount=6.4, puYear=2012, puMonth=3),
#  Row(vendorID='VTS', tpepPickupDateTime=datetime.datetime(2012, 2, 29, 23, 50), tpepDropoffDateTime=datetime.datetime(2012, 3, 1, 0, 3), passengerCount=1, tripDistance=2.18, puLocationId=None, doLocationId=None, startLon=-73.975403, startLat=40.731313, endLon=-73.99111, endLat=40.750223, rateCodeId=1, storeAndFwdFlag=None, paymentType='CRD', fareAmount=8.9, extra=0.5, mtaTax=0.5, improvementSurcharge=None, tipAmount=1.88, tollsAmount=0.0, totalAmount=11.78, puYear=2012, puMonth=3),
#  Row(vendorID='VTS', tpepPickupDateTime=datetime.datetime(2012, 3, 8, 14, 31), tpepDropoffDateTime=datetime.datetime(2012, 3, 8, 14, 49), passengerCount=1, tripDistance=1.43, puLocationId=None, doLocationId=None, startLon=-73.982395, startLat=40.761025, endLon=-73.975887, endLat=40.747637, rateCodeId=1, storeAndFwdFlag=None, paymentType='CRD', fareAmount=10.1, extra=0.0, mtaTax=0.5, improvementSurcharge=None, tipAmount=2.52, tollsAmount=0.0, totalAmount=13.12, puYear=2012, puMonth=3),
#  Row(vendorID='VTS', tpepPickupDateTime=datetime.datetime(2012, 2, 29, 23, 59), tpepDropoffDateTime=datetime.datetime(2012, 3, 1, 0, 17), passengerCount=5, tripDistance=8.65, puLocationId=None, doLocationId=None, startLon=-73.993845, startLat=40.746655, endLon=-73.93843, endLat=40.842785, rateCodeId=1, storeAndFwdFlag=None, paymentType='CSH', fareAmount=21.3, extra=0.5, mtaTax=0.5, improvementSurcharge=None, tipAmount=0.0, tollsAmount=0.0, totalAmount=22.3, puYear=2012, puMonth=3),
#  Row(vendorID='VTS', tpepPickupDateTime=datetime.datetime(2012, 3, 7, 13, 35), tpepDropoffDateTime=datetime.datetime(2012, 3, 7, 13, 39), passengerCount=4, tripDistance=0.85, puLocationId=None, doLocationId=None, startLon=-73.957758, startLat=40.77936, endLon=-73.953065, endLat=40.788727, rateCodeId=1, storeAndFwdFlag=None, paymentType='CRD', fareAmount=4.9, extra=0.0, mtaTax=0.5, improvementSurcharge=None, tipAmount=0.98, tollsAmount=0.0, totalAmount=6.38, puYear=2012, puMonth=3),
#  Row(vendorID='VTS', tpepPickupDateTime=datetime.datetime(2012, 2, 29, 23, 55), tpepDropoffDateTime=datetime.datetime(2012, 3, 1, 0, 0), passengerCount=3, tripDistance=1.14, puLocationId=None, doLocationId=None, startLon=0.0, startLat=0.0, endLon=0.0, endLat=0.0, rateCodeId=1, storeAndFwdFlag=None, paymentType='CRD', fareAmount=4.9, extra=0.5, mtaTax=0.5, improvementSurcharge=None, tipAmount=1.1, tollsAmount=0.0, totalAmount=7.0, puYear=2012, puMonth=3),
#  Row(vendorID='CMT', tpepPickupDateTime=datetime.datetime(2012, 3, 1, 17, 26, 25), tpepDropoffDateTime=datetime.datetime(2012, 3, 1, 17, 45, 42), passengerCount=1, tripDistance=5.1, puLocationId=None, doLocationId=None, startLon=-74.0056, startLat=40.745684, endLon=-73.962165, endLat=40.796419, rateCodeId=1, storeAndFwdFlag='N', paymentType='CSH', fareAmount=15.3, extra=1.0, mtaTax=0.5, improvementSurcharge=None, tipAmount=0.0, tollsAmount=0.0, totalAmount=16.8, puYear=2012, puMonth=3),
#  Row(vendorID='VTS', tpepPickupDateTime=datetime.datetime(2012, 2, 29, 23, 57), tpepDropoffDateTime=datetime.datetime(2012, 3, 1, 0, 7), passengerCount=1, tripDistance=3.0, puLocationId=None, doLocationId=None, startLon=-73.973257, startLat=40.752455, endLon=-73.948798, endLat=40.788737, rateCodeId=1, storeAndFwdFlag=None, paymentType='CRD', fareAmount=8.9, extra=0.5, mtaTax=0.5, improvementSurcharge=None, tipAmount=1.1, tollsAmount=0.0, totalAmount=11.0, puYear=2012, puMonth=3),
#  Row(vendorID='CMT', tpepPickupDateTime=datetime.datetime(2012, 3, 4, 8, 42, 36), tpepDropoffDateTime=datetime.datetime(2012, 3, 4, 8, 48, 49), passengerCount=1, tripDistance=3.1, puLocationId=None, doLocationId=None, startLon=-73.977832, startLat=40.737687, endLon=-73.951895, endLat=40.777126, rateCodeId=1, storeAndFwdFlag='N', paymentType='CSH', fareAmount=8.5, extra=0.0, mtaTax=0.5, improvementSurcharge=None, tipAmount=0.0, tollsAmount=0.0, totalAmount=9.0, puYear=2012, puMonth=3),
#  Row(vendorID='VTS', tpepPickupDateTime=datetime.datetime(2012, 2, 29, 23, 50), tpepDropoffDateTime=datetime.datetime(2012, 3, 1, 0, 50), passengerCount=1, tripDistance=10.87, puLocationId=None, doLocationId=None, startLon=-73.983462, startLat=40.676867, endLon=-73.935982, endLat=40.795357, rateCodeId=1, storeAndFwdFlag=None, paymentType='CRD', fareAmount=36.5, extra=0.5, mtaTax=0.5, improvementSurcharge=None, tipAmount=6.0, tollsAmount=0.0, totalAmount=43.5, puYear=2012, puMonth=3),
#  Row(vendorID='VTS', tpepPickupDateTime=datetime.datetime(2012, 3, 6, 9, 47), tpepDropoffDateTime=datetime.datetime(2012, 3, 6, 9, 53), passengerCount=2, tripDistance=0.51, puLocationId=None, doLocationId=None, startLon=-73.997173, startLat=40.742283, endLon=-73.991058, endLat=40.74484, rateCodeId=1, storeAndFwdFlag=None, paymentType='CSH', fareAmount=4.9, extra=0.0, mtaTax=0.5, improvementSurcharge=None, tipAmount=0.0, tollsAmount=0.0, totalAmount=5.4, puYear=2012, puMonth=3),
#  Row(vendorID='VTS', tpepPickupDateTime=datetime.datetime(2012, 2, 29, 23, 59), tpepDropoffDateTime=datetime.datetime(2012, 3, 1, 0, 14), passengerCount=1, tripDistance=3.89, puLocationId=None, doLocationId=None, startLon=-73.989577, startLat=40.720492, endLon=-73.978402, endLat=40.76273, rateCodeId=1, storeAndFwdFlag=None, paymentType='CRD', fareAmount=11.7, extra=0.5, mtaTax=0.5, improvementSurcharge=None, tipAmount=2.44, tollsAmount=0.0, totalAmount=15.14, puYear=2012, puMonth=3),
#  Row(vendorID='VTS', tpepPickupDateTime=datetime.datetime(2012, 3, 6, 23, 44), tpepDropoffDateTime=datetime.datetime(2012, 3, 6, 23, 59), passengerCount=1, tripDistance=7.51, puLocationId=None, doLocationId=None, startLon=-73.985983, startLat=40.730868, endLon=-73.894293, endLat=40.747857, rateCodeId=1, storeAndFwdFlag=None, paymentType='CRD', fareAmount=18.9, extra=0.5, mtaTax=0.5, improvementSurcharge=None, tipAmount=4.85, tollsAmount=0.0, totalAmount=24.75, puYear=2012, puMonth=3),
#  Row(vendorID='VTS', tpepPickupDateTime=datetime.datetime(2012, 2, 29, 23, 51), tpepDropoffDateTime=datetime.datetime(2012, 3, 1, 0, 0), passengerCount=1, tripDistance=2.66, puLocationId=None, doLocationId=None, startLon=-73.982167, startLat=40.765462, endLon=-73.948042, endLat=40.772847, rateCodeId=1, storeAndFwdFlag=None, paymentType='CRD', fareAmount=8.1, extra=0.5, mtaTax=0.5, improvementSurcharge=None, tipAmount=2.15, tollsAmount=0.0, totalAmount=11.25, puYear=2012, puMonth=3),
#  Row(vendorID='VTS', tpepPickupDateTime=datetime.datetime(2012, 3, 16, 13, 9), tpepDropoffDateTime=datetime.datetime(2012, 3, 16, 13, 30), passengerCount=6, tripDistance=9.54, puLocationId=None, doLocationId=None, startLon=-73.874562, startLat=40.774057, endLon=-73.985867, endLat=40.727805, rateCodeId=1, storeAndFwdFlag=None, paymentType='CRD', fareAmount=22.9, extra=0.0, mtaTax=0.5, improvementSurcharge=None, tipAmount=4.58, tollsAmount=4.8, totalAmount=32.78, puYear=2012, puMonth=3),
#  Row(vendorID='VTS', tpepPickupDateTime=datetime.datetime(2012, 2, 29, 23, 49), tpepDropoffDateTime=datetime.datetime(2012, 3, 1, 0, 5), passengerCount=1, tripDistance=3.68, puLocationId=None, doLocationId=None, startLon=-73.98309, startLat=40.761755, endLon=-74.011027, endLat=40.713482, rateCodeId=1, storeAndFwdFlag=None, paymentType='CSH', fareAmount=11.3, extra=0.5, mtaTax=0.5, improvementSurcharge=None, tipAmount=0.0, tollsAmount=0.0, totalAmount=12.3, puYear=2012, puMonth=3),
#  Row(vendorID='VTS', tpepPickupDateTime=datetime.datetime(2012, 3, 9, 19, 37), tpepDropoffDateTime=datetime.datetime(2012, 3, 9, 19, 57), passengerCount=1, tripDistance=2.92, puLocationId=None, doLocationId=None, startLon=-73.985518, startLat=40.743737, endLon=-73.988987, endLat=40.774395, rateCodeId=1, storeAndFwdFlag=None, paymentType='CRD', fareAmount=12.5, extra=1.0, mtaTax=0.5, improvementSurcharge=None, tipAmount=2.7, tollsAmount=0.0, totalAmount=16.7, puYear=2012, puMonth=3),
#  Row(vendorID='VTS', tpepPickupDateTime=datetime.datetime(2012, 2, 29, 23, 47), tpepDropoffDateTime=datetime.datetime(2012, 3, 1, 0, 1), passengerCount=2, tripDistance=3.57, puLocationId=None, doLocationId=None, startLon=-73.977757, startLat=40.786812, endLon=-73.99394, endLat=40.744222, rateCodeId=1, storeAndFwdFlag=None, paymentType='CSH', fareAmount=11.7, extra=0.5, mtaTax=0.5, improvementSurcharge=None, tipAmount=0.0, tollsAmount=0.0, totalAmount=12.7, puYear=2012, puMonth=3),
#  Row(vendorID='CMT', tpepPickupDateTime=datetime.datetime(2012, 3, 4, 23, 7, 56), tpepDropoffDateTime=datetime.datetime(2012, 3, 4, 23, 15, 6), passengerCount=2, tripDistance=1.2, puLocationId=None, doLocationId=None, startLon=-73.985468, startLat=40.761924, endLon=-73.982443, endLat=40.755551, rateCodeId=1, storeAndFwdFlag='N', paymentType='CSH', fareAmount=6.1, extra=0.5, mtaTax=0.5, improvementSurcharge=None, tipAmount=0.0, tollsAmount=0.0, totalAmount=7.1, puYear=2012, puMonth=3),
#  Row(vendorID='VTS', tpepPickupDateTime=datetime.datetime(2012, 2, 29, 23, 28), tpepDropoffDateTime=datetime.datetime(2012, 3, 1, 0, 1), passengerCount=2, tripDistance=19.33, puLocationId=None, doLocationId=None, startLon=-73.783178, startLat=40.648595, endLon=-74.004132, endLat=40.718547, rateCodeId=2, storeAndFwdFlag=None, paymentType='CSH', fareAmount=45.0, extra=0.0, mtaTax=0.5, improvementSurcharge=None, tipAmount=0.0, tollsAmount=4.8, totalAmount=50.3, puYear=2012, puMonth=3),
#  Row(vendorID='CMT', tpepPickupDateTime=datetime.datetime(2012, 3, 3, 21, 26, 19), tpepDropoffDateTime=datetime.datetime(2012, 3, 3, 21, 51, 16), passengerCount=1, tripDistance=5.4, puLocationId=None, doLocationId=None, startLon=-73.985112, startLat=40.732457, endLon=-73.960579, endLat=40.797194, rateCodeId=1, storeAndFwdFlag='N', paymentType='CSH', fareAmount=16.9, extra=0.5, mtaTax=0.5, improvementSurcharge=None, tipAmount=0.0, tollsAmount=0.0, totalAmount=17.9, puYear=2012, puMonth=3),
#  Row(vendorID='VTS', tpepPickupDateTime=datetime.datetime(2012, 2, 29, 23, 47), tpepDropoffDateTime=datetime.datetime(2012, 3, 1, 0, 0), passengerCount=1, tripDistance=4.86, puLocationId=None, doLocationId=None, startLon=-74.006997, startLat=40.729612, endLon=-73.978973, endLat=40.783367, rateCodeId=1, storeAndFwdFlag=None, paymentType='CRD', fareAmount=13.3, extra=0.5, mtaTax=0.5, improvementSurcharge=None, tipAmount=1.5, tollsAmount=0.0, totalAmount=15.8, puYear=2012, puMonth=3),
#  Row(vendorID='VTS', tpepPickupDateTime=datetime.datetime(2012, 3, 8, 9, 8), tpepDropoffDateTime=datetime.datetime(2012, 3, 8, 9, 19), passengerCount=1, tripDistance=2.43, puLocationId=None, doLocationId=None, startLon=-74.0081, startLat=40.722785, endLon=-73.990845, endLat=40.752785, rateCodeId=1, storeAndFwdFlag=None, paymentType='CRD', fareAmount=8.9, extra=0.0, mtaTax=0.5, improvementSurcharge=None, tipAmount=1.78, tollsAmount=0.0, totalAmount=11.18, puYear=2012, puMonth=3),
#  Row(vendorID='VTS', tpepPickupDateTime=datetime.datetime(2012, 2, 29, 23, 43), tpepDropoffDateTime=datetime.datetime(2012, 3, 1, 0, 2), passengerCount=2, tripDistance=5.32, puLocationId=None, doLocationId=None, startLon=-73.989287, startLat=40.730325, endLon=-73.976305, endLat=40.787293, rateCodeId=1, storeAndFwdFlag=None, paymentType='CRD', fareAmount=14.5, extra=0.5, mtaTax=0.5, improvementSurcharge=None, tipAmount=3.0, tollsAmount=0.0, totalAmount=18.5, puYear=2012, puMonth=3),
#  Row(vendorID='VTS', tpepPickupDateTime=datetime.datetime(2012, 3, 11, 13, 31), tpepDropoffDateTime=datetime.datetime(2012, 3, 11, 13, 37), passengerCount=1, tripDistance=1.07, puLocationId=None, doLocationId=None, startLon=-73.974182, startLat=40.763405, endLon=-73.985557, endLat=40.75541, rateCodeId=1, storeAndFwdFlag=None, paymentType='CRD', fareAmount=5.7, extra=0.0, mtaTax=0.5, improvementSurcharge=None, tipAmount=0.6, tollsAmount=0.0, totalAmount=6.8, puYear=2012, puMonth=3),
#  Row(vendorID='VTS', tpepPickupDateTime=datetime.datetime(2012, 2, 29, 23, 54), tpepDropoffDateTime=datetime.datetime(2012, 3, 1, 0, 9), passengerCount=3, tripDistance=4.98, puLocationId=None, doLocationId=None, startLon=-73.959965, startLat=40.782085, endLon=-74.005695, endLat=40.725688, rateCodeId=1, storeAndFwdFlag=None, paymentType='CSH', fareAmount=13.3, extra=0.5, mtaTax=0.5, improvementSurcharge=None, tipAmount=0.0, tollsAmount=0.0, totalAmount=14.3, puYear=2012, puMonth=3),
#  Row(vendorID='VTS', tpepPickupDateTime=datetime.datetime(2012, 3, 5, 22, 47), tpepDropoffDateTime=datetime.datetime(2012, 3, 5, 22, 52), passengerCount=5, tripDistance=0.86, puLocationId=None, doLocationId=None, startLon=-73.984632, startLat=40.759127, endLon=-73.98614, endLat=40.756827, rateCodeId=1, storeAndFwdFlag=None, paymentType='CSH', fareAmount=4.9, extra=0.5, mtaTax=0.5, improvementSurcharge=None, tipAmount=0.0, tollsAmount=0.0, totalAmount=5.9, puYear=2012, puMonth=3),
#  Row(vendorID='VTS', tpepPickupDateTime=datetime.datetime(2012, 2, 29, 23, 53), tpepDropoffDateTime=datetime.datetime(2012, 3, 1, 0, 10), passengerCount=2, tripDistance=4.83, puLocationId=None, doLocationId=None, startLon=0.0, startLat=0.0, endLon=0.0, endLat=0.0, rateCodeId=1, storeAndFwdFlag=None, paymentType='CSH', fareAmount=14.1, extra=0.5, mtaTax=0.5, improvementSurcharge=None, tipAmount=0.0, tollsAmount=0.0, totalAmount=15.1, puYear=2012, puMonth=3),
#  Row(vendorID='VTS', tpepPickupDateTime=datetime.datetime(2012, 3, 10, 23, 0), tpepDropoffDateTime=datetime.datetime(2012, 3, 10, 23, 10), passengerCount=5, tripDistance=2.6, puLocationId=None, doLocationId=None, startLon=-73.97853, startLat=40.741242, endLon=-73.96075, endLat=40.769332, rateCodeId=1, storeAndFwdFlag=None, paymentType='CSH', fareAmount=8.5, extra=0.5, mtaTax=0.5, improvementSurcharge=None, tipAmount=0.0, tollsAmount=0.0, totalAmount=9.5, puYear=2012, puMonth=3),
#  Row(vendorID='VTS', tpepPickupDateTime=datetime.datetime(2012, 2, 29, 23, 56), tpepDropoffDateTime=datetime.datetime(2012, 3, 1, 0, 21), passengerCount=5, tripDistance=6.48, puLocationId=None, doLocationId=None, startLon=-73.995352, startLat=40.764562, endLon=-73.958112, endLat=40.713232, rateCodeId=1, storeAndFwdFlag=None, paymentType='CSH', fareAmount=18.5, extra=0.5, mtaTax=0.5, improvementSurcharge=None, tipAmount=0.0, tollsAmount=0.0, totalAmount=19.5, puYear=2012, puMonth=3),
#  Row(vendorID='VTS', tpepPickupDateTime=datetime.datetime(2012, 3, 6, 17, 47), tpepDropoffDateTime=datetime.datetime(2012, 3, 6, 17, 56), passengerCount=5, tripDistance=1.83, puLocationId=None, doLocationId=None, startLon=-73.968497, startLat=40.759067, endLon=-73.952535, endLat=40.780655, rateCodeId=1, storeAndFwdFlag=None, paymentType='CSH', fareAmount=7.3, extra=1.0, mtaTax=0.5, improvementSurcharge=None, tipAmount=0.0, tollsAmount=0.0, totalAmount=8.8, puYear=2012, puMonth=3),
#  Row(vendorID='VTS', tpepPickupDateTime=datetime.datetime(2012, 2, 29, 23, 40), tpepDropoffDateTime=datetime.datetime(2012, 3, 1, 0, 12), passengerCount=1, tripDistance=20.62, puLocationId=None, doLocationId=None, startLon=-73.789778, startLat=40.64497, endLon=-73.931782, endLat=40.858102, rateCodeId=2, storeAndFwdFlag=None, paymentType='CRD', fareAmount=45.0, extra=0.0, mtaTax=0.5, improvementSurcharge=None, tipAmount=11.25, tollsAmount=4.8, totalAmount=61.55, puYear=2012, puMonth=3),
#  Row(vendorID='VTS', tpepPickupDateTime=datetime.datetime(2012, 3, 8, 4, 14), tpepDropoffDateTime=datetime.datetime(2012, 3, 8, 4, 16), passengerCount=1, tripDistance=0.4, puLocationId=None, doLocationId=None, startLon=-73.944742, startLat=40.834158, endLon=-73.94853, endLat=40.829333, rateCodeId=1, storeAndFwdFlag=None, paymentType='CSH', fareAmount=3.3, extra=0.5, mtaTax=0.5, improvementSurcharge=None, tipAmount=0.0, tollsAmount=0.0, totalAmount=4.3, puYear=2012, puMonth=3),
#  Row(vendorID='CMT', tpepPickupDateTime=datetime.datetime(2012, 2, 29, 23, 49, 26), tpepDropoffDateTime=datetime.datetime(2012, 3, 1, 0, 1, 18), passengerCount=1, tripDistance=3.2, puLocationId=None, doLocationId=None, startLon=-74.00281, startLat=40.728592, endLon=-73.962615, endLat=40.7125, rateCodeId=1, storeAndFwdFlag='N', paymentType='CSH', fareAmount=10.5, extra=0.5, mtaTax=0.5, improvementSurcharge=None, tipAmount=0.0, tollsAmount=0.0, totalAmount=11.5, puYear=2012, puMonth=3),
#  Row(vendorID='VTS', tpepPickupDateTime=datetime.datetime(2012, 3, 9, 0, 41), tpepDropoffDateTime=datetime.datetime(2012, 3, 9, 1, 29), passengerCount=5, tripDistance=22.63, puLocationId=None, doLocationId=None, startLon=-73.968002, startLat=40.792207, endLon=-73.980975, endLat=40.613532, rateCodeId=1, storeAndFwdFlag=None, paymentType='CSH', fareAmount=50.9, extra=0.5, mtaTax=0.5, improvementSurcharge=None, tipAmount=0.0, tollsAmount=0.0, totalAmount=51.9, puYear=2012, puMonth=3),
#  Row(vendorID='CMT', tpepPickupDateTime=datetime.datetime(2012, 2, 29, 23, 49, 5), tpepDropoffDateTime=datetime.datetime(2012, 3, 1, 0, 13, 25), passengerCount=1, tripDistance=11.6, puLocationId=None, doLocationId=None, startLon=-73.984926, startLat=40.74841, endLon=-73.816347, endLat=40.712035, rateCodeId=1, storeAndFwdFlag='N', paymentType='CSH', fareAmount=26.9, extra=0.5, mtaTax=0.5, improvementSurcharge=None, tipAmount=0.0, tollsAmount=4.8, totalAmount=32.7, puYear=2012, puMonth=3),
#  Row(vendorID='VTS', tpepPickupDateTime=datetime.datetime(2012, 3, 10, 19, 41), tpepDropoffDateTime=datetime.datetime(2012, 3, 10, 19, 47), passengerCount=3, tripDistance=0.9, puLocationId=None, doLocationId=None, startLon=-74.006697, startLat=40.730645, endLon=-74.000612, endLat=40.742437, rateCodeId=1, storeAndFwdFlag=None, paymentType='CSH', fareAmount=5.3, extra=0.0, mtaTax=0.5, improvementSurcharge=None, tipAmount=0.0, tollsAmount=0.0, totalAmount=5.8, puYear=2012, puMonth=3),
#  Row(vendorID='CMT', tpepPickupDateTime=datetime.datetime(2012, 2, 29, 23, 56, 51), tpepDropoffDateTime=datetime.datetime(2012, 3, 1, 0, 13, 30), passengerCount=1, tripDistance=6.3, puLocationId=None, doLocationId=None, startLon=-73.966967, startLat=40.804032, endLon=-73.991303, endLat=40.736663, rateCodeId=1, storeAndFwdFlag='N', paymentType='CSH', fareAmount=16.5, extra=0.5, mtaTax=0.5, improvementSurcharge=None, tipAmount=0.0, tollsAmount=0.0, totalAmount=17.5, puYear=2012, puMonth=3),
#  Row(vendorID='CMT', tpepPickupDateTime=datetime.datetime(2012, 3, 1, 16, 44, 57), tpepDropoffDateTime=datetime.datetime(2012, 3, 1, 17, 38, 58), passengerCount=4, tripDistance=19.0, puLocationId=None, doLocationId=None, startLon=-73.781262, startLat=40.644917, endLon=-73.978287, endLat=40.766583, rateCodeId=2, storeAndFwdFlag='N', paymentType='CSH', fareAmount=45.0, extra=0.0, mtaTax=0.5, improvementSurcharge=None, tipAmount=0.0, tollsAmount=4.8, totalAmount=50.3, puYear=2012, puMonth=3),
#  Row(vendorID='CMT', tpepPickupDateTime=datetime.datetime(2012, 2, 29, 23, 49, 22), tpepDropoffDateTime=datetime.datetime(2012, 3, 1, 0, 4, 12), passengerCount=1, tripDistance=4.5, puLocationId=None, doLocationId=None, startLon=-73.975159, startLat=40.787705, endLon=-73.92324, endLat=40.808701, rateCodeId=1, storeAndFwdFlag='N', paymentType='CSH', fareAmount=12.9, extra=0.5, mtaTax=0.5, improvementSurcharge=None, tipAmount=0.0, tollsAmount=0.0, totalAmount=13.9, puYear=2012, puMonth=3),
#  Row(vendorID='VTS', tpepPickupDateTime=datetime.datetime(2012, 3, 5, 11, 34), tpepDropoffDateTime=datetime.datetime(2012, 3, 5, 11, 48), passengerCount=1, tripDistance=3.73, puLocationId=None, doLocationId=None, startLon=-74.011632, startLat=40.720267, endLon=-73.984172, endLat=40.754797, rateCodeId=1, storeAndFwdFlag=None, paymentType='CRD', fareAmount=11.7, extra=0.0, mtaTax=0.5, improvementSurcharge=None, tipAmount=2.34, tollsAmount=0.0, totalAmount=14.54, puYear=2012, puMonth=3),
#  Row(vendorID='CMT', tpepPickupDateTime=datetime.datetime(2012, 2, 29, 23, 57, 57), tpepDropoffDateTime=datetime.datetime(2012, 3, 1, 0, 7, 31), passengerCount=1, tripDistance=2.5, puLocationId=None, doLocationId=None, startLon=-73.949531, startLat=40.78098, endLon=-73.975767, endLat=40.755122, rateCodeId=1, storeAndFwdFlag='N', paymentType='CRD', fareAmount=8.5, extra=0.5, mtaTax=0.5, improvementSurcharge=None, tipAmount=1.0, tollsAmount=0.0, totalAmount=10.5, puYear=2012, puMonth=3),
#  Row(vendorID='VTS', tpepPickupDateTime=datetime.datetime(2012, 3, 11, 15, 10), tpepDropoffDateTime=datetime.datetime(2012, 3, 11, 15, 15), passengerCount=1, tripDistance=0.64, puLocationId=None, doLocationId=None, startLon=-73.987527, startLat=40.765397, endLon=-73.98214, endLat=40.75931, rateCodeId=1, storeAndFwdFlag=None, paymentType='CSH', fareAmount=4.9, extra=0.0, mtaTax=0.5, improvementSurcharge=None, tipAmount=0.0, tollsAmount=0.0, totalAmount=5.4, puYear=2012, puMonth=3),
#  Row(vendorID='CMT', tpepPickupDateTime=datetime.datetime(2012, 2, 29, 23, 42, 53), tpepDropoffDateTime=datetime.datetime(2012, 3, 1, 0, 3, 40), passengerCount=1, tripDistance=5.2, puLocationId=None, doLocationId=None, startLon=-73.985189, startLat=40.741788, endLon=-73.999776, endLat=40.683369, rateCodeId=1, storeAndFwdFlag='N', paymentType='CRD', fareAmount=16.1, extra=0.5, mtaTax=0.5, improvementSurcharge=None, tipAmount=5.13, tollsAmount=0.0, totalAmount=22.23, puYear=2012, puMonth=3),
#  Row(vendorID='VTS', tpepPickupDateTime=datetime.datetime(2012, 3, 11, 1, 22), tpepDropoffDateTime=datetime.datetime(2012, 3, 11, 1, 27), passengerCount=5, tripDistance=0.77, puLocationId=None, doLocationId=None, startLon=-74.002165, startLat=40.708385, endLon=-73.982115, endLat=40.728007, rateCodeId=1, storeAndFwdFlag=None, paymentType='CSH', fareAmount=4.9, extra=0.5, mtaTax=0.5, improvementSurcharge=None, tipAmount=0.0, tollsAmount=0.0, totalAmount=5.9, puYear=2012, puMonth=3),
#  Row(vendorID='CMT', tpepPickupDateTime=datetime.datetime(2012, 2, 29, 23, 44, 43), tpepDropoffDateTime=datetime.datetime(2012, 3, 1, 0, 8, 12), passengerCount=1, tripDistance=14.1, puLocationId=None, doLocationId=None, startLon=-73.955018, startLat=40.777753, endLon=-73.971972, endLat=40.633706, rateCodeId=1, storeAndFwdFlag='N', paymentType='CSH', fareAmount=31.7, extra=0.5, mtaTax=0.5, improvementSurcharge=None, tipAmount=0.0, tollsAmount=4.8, totalAmount=37.5, puYear=2012, puMonth=3),
#  Row(vendorID='VTS', tpepPickupDateTime=datetime.datetime(2012, 3, 5, 14, 14), tpepDropoffDateTime=datetime.datetime(2012, 3, 5, 14, 20), passengerCount=3, tripDistance=0.78, puLocationId=None, doLocationId=None, startLon=-73.990388, startLat=40.756388, endLon=-73.996248, endLat=40.763917, rateCodeId=1, storeAndFwdFlag=None, paymentType='CSH', fareAmount=5.3, extra=0.0, mtaTax=0.5, improvementSurcharge=None, tipAmount=0.0, tollsAmount=0.0, totalAmount=5.8, puYear=2012, puMonth=3),
#  Row(vendorID='CMT', tpepPickupDateTime=datetime.datetime(2012, 2, 29, 23, 55, 46), tpepDropoffDateTime=datetime.datetime(2012, 3, 1, 0, 5, 2), passengerCount=1, tripDistance=1.8, puLocationId=None, doLocationId=None, startLon=-74.006604, startLat=40.739769, endLon=-73.994188, endLat=40.758891, rateCodeId=1, storeAndFwdFlag='N', paymentType='CRD', fareAmount=7.7, extra=0.5, mtaTax=0.5, improvementSurcharge=None, tipAmount=1.0, tollsAmount=0.0, totalAmount=9.7, puYear=2012, puMonth=3),
#  Row(vendorID='VTS', tpepPickupDateTime=datetime.datetime(2012, 3, 2, 8, 53), tpepDropoffDateTime=datetime.datetime(2012, 3, 2, 8, 59), passengerCount=1, tripDistance=0.75, puLocationId=None, doLocationId=None, startLon=-74.011455, startLat=40.708043, endLon=-74.012948, endLat=40.7065, rateCodeId=1, storeAndFwdFlag=None, paymentType='CRD', fareAmount=4.9, extra=0.0, mtaTax=0.5, improvementSurcharge=None, tipAmount=3.0, tollsAmount=0.0, totalAmount=8.4, puYear=2012, puMonth=3),
#  Row(vendorID='CMT', tpepPickupDateTime=datetime.datetime(2012, 2, 29, 23, 38, 9), tpepDropoffDateTime=datetime.datetime(2012, 3, 1, 0, 4, 33), passengerCount=1, tripDistance=10.9, puLocationId=None, doLocationId=None, startLon=-73.992842, startLat=40.748627, endLon=-74.015795, endLat=40.629541, rateCodeId=1, storeAndFwdFlag='N', paymentType='CRD', fareAmount=26.1, extra=0.5, mtaTax=0.5, improvementSurcharge=None, tipAmount=3.5, tollsAmount=0.0, totalAmount=30.6, puYear=2012, puMonth=3),
#  Row(vendorID='VTS', tpepPickupDateTime=datetime.datetime(2012, 3, 12, 9, 50), tpepDropoffDateTime=datetime.datetime(2012, 3, 12, 10, 7), passengerCount=1, tripDistance=2.02, puLocationId=None, doLocationId=None, startLon=-73.995765, startLat=40.738883, endLon=-73.975033, endLat=40.760787, rateCodeId=1, storeAndFwdFlag=None, paymentType='CRD', fareAmount=10.1, extra=0.0, mtaTax=0.5, improvementSurcharge=None, tipAmount=1.0, tollsAmount=0.0, totalAmount=11.6, puYear=2012, puMonth=3),
#  Row(vendorID='CMT', tpepPickupDateTime=datetime.datetime(2012, 2, 29, 23, 33, 30), tpepDropoffDateTime=datetime.datetime(2012, 3, 1, 0, 4, 34), passengerCount=1, tripDistance=8.4, puLocationId=None, doLocationId=None, startLon=-74.005697, startLat=40.740454, endLon=-73.878294, endLat=40.747405, rateCodeId=1, storeAndFwdFlag='N', paymentType='CSH', fareAmount=23.3, extra=0.5, mtaTax=0.5, improvementSurcharge=None, tipAmount=0.0, tollsAmount=0.0, totalAmount=24.3, puYear=2012, puMonth=3),
#  Row(vendorID='CMT', tpepPickupDateTime=datetime.datetime(2012, 3, 3, 13, 12, 56), tpepDropoffDateTime=datetime.datetime(2012, 3, 3, 13, 35, 38), passengerCount=1, tripDistance=2.6, puLocationId=None, doLocationId=None, startLon=-73.996581, startLat=40.747876, endLon=-73.984946, endLat=40.769137, rateCodeId=1, storeAndFwdFlag='N', paymentType='CSH', fareAmount=13.3, extra=0.0, mtaTax=0.5, improvementSurcharge=None, tipAmount=0.0, tollsAmount=0.0, totalAmount=13.8, puYear=2012, puMonth=3),
#  Row(vendorID='VTS', tpepPickupDateTime=datetime.datetime(2012, 2, 29, 23, 33), tpepDropoffDateTime=datetime.datetime(2012, 3, 1, 0, 2), passengerCount=1, tripDistance=7.9, puLocationId=None, doLocationId=None, startLon=0.0, startLat=0.0, endLon=0.0, endLat=0.0, rateCodeId=1, storeAndFwdFlag=None, paymentType='CSH', fareAmount=22.9, extra=0.5, mtaTax=0.5, improvementSurcharge=None, tipAmount=0.0, tollsAmount=0.0, totalAmount=23.9, puYear=2012, puMonth=3),
#  Row(vendorID='VTS', tpepPickupDateTime=datetime.datetime(2012, 3, 6, 15, 26), tpepDropoffDateTime=datetime.datetime(2012, 3, 6, 15, 41), passengerCount=4, tripDistance=1.73, puLocationId=None, doLocationId=None, startLon=-73.977592, startLat=40.764602, endLon=-73.962285, endLat=40.75545, rateCodeId=1, storeAndFwdFlag=None, paymentType='CSH', fareAmount=9.3, extra=0.0, mtaTax=0.5, improvementSurcharge=None, tipAmount=0.0, tollsAmount=0.0, totalAmount=9.8, puYear=2012, puMonth=3),
#  Row(vendorID='VTS', tpepPickupDateTime=datetime.datetime(2012, 2, 29, 23, 53), tpepDropoffDateTime=datetime.datetime(2012, 3, 1, 0, 11), passengerCount=4, tripDistance=4.88, puLocationId=None, doLocationId=None, startLon=-73.981515, startLat=40.741028, endLon=-73.960123, endLat=40.79792, rateCodeId=1, storeAndFwdFlag=None, paymentType='CSH', fareAmount=14.9, extra=0.5, mtaTax=0.5, improvementSurcharge=None, tipAmount=0.0, tollsAmount=0.0, totalAmount=15.9, puYear=2012, puMonth=3),
#  Row(vendorID='VTS', tpepPickupDateTime=datetime.datetime(2012, 3, 7, 14, 50), tpepDropoffDateTime=datetime.datetime(2012, 3, 7, 15, 0), passengerCount=3, tripDistance=1.46, puLocationId=None, doLocationId=None, startLon=-73.992037, startLat=40.76971, endLon=-73.99593, endLat=40.753935, rateCodeId=1, storeAndFwdFlag=None, paymentType='CSH', fareAmount=7.3, extra=0.0, mtaTax=0.5, improvementSurcharge=None, tipAmount=0.0, tollsAmount=0.0, totalAmount=7.8, puYear=2012, puMonth=3),
#  Row(vendorID='VTS', tpepPickupDateTime=datetime.datetime(2012, 2, 29, 23, 47), tpepDropoffDateTime=datetime.datetime(2012, 3, 1, 0, 4), passengerCount=1, tripDistance=5.79, puLocationId=None, doLocationId=None, startLon=-73.992388, startLat=40.72472, endLon=-73.969768, endLat=40.786323, rateCodeId=1, storeAndFwdFlag=None, paymentType='CRD', fareAmount=14.9, extra=0.5, mtaTax=0.5, improvementSurcharge=None, tipAmount=3.08, tollsAmount=0.0, totalAmount=18.98, puYear=2012, puMonth=3),
#  Row(vendorID='VTS', tpepPickupDateTime=datetime.datetime(2012, 3, 9, 10, 22), tpepDropoffDateTime=datetime.datetime(2012, 3, 9, 10, 31), passengerCount=2, tripDistance=1.92, puLocationId=None, doLocationId=None, startLon=-73.953458, startLat=40.767257, endLon=-73.955215, endLat=40.786672, rateCodeId=1, storeAndFwdFlag=None, paymentType='CRD', fareAmount=7.7, extra=0.0, mtaTax=0.5, improvementSurcharge=None, tipAmount=1.0, tollsAmount=0.0, totalAmount=9.2, puYear=2012, puMonth=3),
#  Row(vendorID='VTS', tpepPickupDateTime=datetime.datetime(2012, 2, 29, 23, 57), tpepDropoffDateTime=datetime.datetime(2012, 3, 1, 0, 1), passengerCount=1, tripDistance=0.68, puLocationId=None, doLocationId=None, startLon=-73.981753, startLat=40.729997, endLon=-73.980847, endLat=40.723822, rateCodeId=1, storeAndFwdFlag=None, paymentType='CSH', fareAmount=4.1, extra=0.5, mtaTax=0.5, improvementSurcharge=None, tipAmount=0.0, tollsAmount=0.0, totalAmount=5.1, puYear=2012, puMonth=3),
#  Row(vendorID='VTS', tpepPickupDateTime=datetime.datetime(2012, 3, 2, 18, 50), tpepDropoffDateTime=datetime.datetime(2012, 3, 2, 19, 6), passengerCount=1, tripDistance=8.26, puLocationId=None, doLocationId=None, startLon=-73.871077, startLat=40.773862, endLon=-73.974377, endLat=40.745822, rateCodeId=1, storeAndFwdFlag=None, paymentType='CRD', fareAmount=20.1, extra=1.0, mtaTax=0.5, improvementSurcharge=None, tipAmount=3.3, tollsAmount=4.8, totalAmount=29.7, puYear=2012, puMonth=3),
#  Row(vendorID='VTS', tpepPickupDateTime=datetime.datetime(2012, 2, 29, 23, 52), tpepDropoffDateTime=datetime.datetime(2012, 3, 1, 0, 24), passengerCount=2, tripDistance=8.66, puLocationId=None, doLocationId=None, startLon=-73.991817, startLat=40.750157, endLon=-73.94504, endLat=40.649157, rateCodeId=1, storeAndFwdFlag=None, paymentType='CSH', fareAmount=23.7, extra=0.5, mtaTax=0.5, improvementSurcharge=None, tipAmount=0.0, tollsAmount=0.0, totalAmount=24.7, puYear=2012, puMonth=3),
#  Row(vendorID='VTS', tpepPickupDateTime=datetime.datetime(2012, 3, 2, 12, 40), tpepDropoffDateTime=datetime.datetime(2012, 3, 2, 12, 51), passengerCount=5, tripDistance=2.56, puLocationId=None, doLocationId=None, startLon=-74.015055, startLat=40.70929, endLon=-74.001255, endLat=40.736937, rateCodeId=1, storeAndFwdFlag=None, paymentType='CSH', fareAmount=8.9, extra=0.0, mtaTax=0.5, improvementSurcharge=None, tipAmount=0.0, tollsAmount=0.0, totalAmount=9.4, puYear=2012, puMonth=3),
#  Row(vendorID='VTS', tpepPickupDateTime=datetime.datetime(2012, 2, 29, 23, 50), tpepDropoffDateTime=datetime.datetime(2012, 3, 1, 0, 9), passengerCount=1, tripDistance=4.6, puLocationId=None, doLocationId=None, startLon=-74.001583, startLat=40.746245, endLon=-73.956425, endLat=40.71331, rateCodeId=1, storeAndFwdFlag=None, paymentType='CRD', fareAmount=13.7, extra=0.5, mtaTax=0.5, improvementSurcharge=None, tipAmount=2.84, tollsAmount=0.0, totalAmount=17.54, puYear=2012, puMonth=3),
#  Row(vendorID='VTS', tpepPickupDateTime=datetime.datetime(2012, 3, 1, 19, 26), tpepDropoffDateTime=datetime.datetime(2012, 3, 1, 19, 33), passengerCount=1, tripDistance=1.18, puLocationId=None, doLocationId=None, startLon=-73.991322, startLat=40.733187, endLon=-73.975497, endLat=40.732977, rateCodeId=1, storeAndFwdFlag=None, paymentType='CSH', fareAmount=5.3, extra=1.0, mtaTax=0.5, improvementSurcharge=None, tipAmount=0.0, tollsAmount=0.0, totalAmount=6.8, puYear=2012, puMonth=3),
#  Row(vendorID='VTS', tpepPickupDateTime=datetime.datetime(2012, 2, 29, 23, 49), tpepDropoffDateTime=datetime.datetime(2012, 3, 1, 0, 1), passengerCount=1, tripDistance=3.3, puLocationId=None, doLocationId=None, startLon=-73.968202, startLat=40.75527, endLon=-74.006063, endLat=40.73522, rateCodeId=1, storeAndFwdFlag=None, paymentType='CRD', fareAmount=10.1, extra=0.5, mtaTax=0.5, improvementSurcharge=None, tipAmount=2.12, tollsAmount=0.0, totalAmount=13.22, puYear=2012, puMonth=3),
#  Row(vendorID='VTS', tpepPickupDateTime=datetime.datetime(2012, 3, 8, 6, 35), tpepDropoffDateTime=datetime.datetime(2012, 3, 8, 6, 43), passengerCount=5, tripDistance=1.9, puLocationId=None, doLocationId=None, startLon=-73.956512, startLat=40.77569, endLon=-73.97789, endLat=40.763375, rateCodeId=1, storeAndFwdFlag=None, paymentType='CSH', fareAmount=7.3, extra=0.0, mtaTax=0.5, improvementSurcharge=None, tipAmount=0.0, tollsAmount=0.0, totalAmount=7.8, puYear=2012, puMonth=3),
#  Row(vendorID='VTS', tpepPickupDateTime=datetime.datetime(2012, 2, 29, 23, 51), tpepDropoffDateTime=datetime.datetime(2012, 3, 1, 0, 3), passengerCount=6, tripDistance=4.68, puLocationId=None, doLocationId=None, startLon=-73.952143, startLat=40.769, endLon=-73.988462, endLat=40.722852, rateCodeId=1, storeAndFwdFlag=None, paymentType='CSH', fareAmount=12.9, extra=0.5, mtaTax=0.5, improvementSurcharge=None, tipAmount=0.0, tollsAmount=0.0, totalAmount=13.9, puYear=2012, puMonth=3),
#  Row(vendorID='VTS', tpepPickupDateTime=datetime.datetime(2012, 3, 15, 0, 25), tpepDropoffDateTime=datetime.datetime(2012, 3, 15, 0, 39), passengerCount=1, tripDistance=6.16, puLocationId=None, doLocationId=None, startLon=-74.007507, startLat=40.707457, endLon=-73.975105, endLat=40.647777, rateCodeId=1, storeAndFwdFlag=None, paymentType='CRD', fareAmount=16.1, extra=0.5, mtaTax=0.5, improvementSurcharge=None, tipAmount=4.15, tollsAmount=4.8, totalAmount=26.05, puYear=2012, puMonth=3),
#  Row(vendorID='VTS', tpepPickupDateTime=datetime.datetime(2012, 2, 29, 23, 39), tpepDropoffDateTime=datetime.datetime(2012, 3, 1, 0, 4), passengerCount=1, tripDistance=8.05, puLocationId=None, doLocationId=None, startLon=-74.016308, startLat=40.710583, endLon=-73.955042, endLat=40.801447, rateCodeId=1, storeAndFwdFlag=None, paymentType='CRD', fareAmount=22.1, extra=0.5, mtaTax=0.5, improvementSurcharge=None, tipAmount=6.78, tollsAmount=0.0, totalAmount=29.88, puYear=2012, puMonth=3),
#  Row(vendorID='VTS', tpepPickupDateTime=datetime.datetime(2012, 3, 14, 10, 36), tpepDropoffDateTime=datetime.datetime(2012, 3, 14, 10, 46), passengerCount=1, tripDistance=1.04, puLocationId=None, doLocationId=None, startLon=-73.965, startLat=40.791828, endLon=-73.948177, endLat=40.784652, rateCodeId=1, storeAndFwdFlag=None, paymentType='CRD', fareAmount=7.3, extra=0.0, mtaTax=0.5, improvementSurcharge=None, tipAmount=2.0, tollsAmount=0.0, totalAmount=9.8, puYear=2012, puMonth=3),
#  Row(vendorID='VTS', tpepPickupDateTime=datetime.datetime(2012, 2, 29, 23, 53), tpepDropoffDateTime=datetime.datetime(2012, 3, 1, 0, 21), passengerCount=6, tripDistance=5.86, puLocationId=None, doLocationId=None, startLon=-73.98604, startLat=40.750057, endLon=-73.966293, endLat=40.690617, rateCodeId=1, storeAndFwdFlag=None, paymentType='CSH', fareAmount=18.9, extra=0.5, mtaTax=0.5, improvementSurcharge=None, tipAmount=0.0, tollsAmount=0.0, totalAmount=19.9, puYear=2012, puMonth=3),
#  Row(vendorID='VTS', tpepPickupDateTime=datetime.datetime(2012, 3, 2, 19, 0), tpepDropoffDateTime=datetime.datetime(2012, 3, 2, 19, 5), passengerCount=5, tripDistance=0.63, puLocationId=None, doLocationId=None, startLon=-73.988647, startLat=40.720157, endLon=-73.989517, endLat=40.7141, rateCodeId=1, storeAndFwdFlag=None, paymentType='CSH', fareAmount=4.5, extra=1.0, mtaTax=0.5, improvementSurcharge=None, tipAmount=0.0, tollsAmount=0.0, totalAmount=6.0, puYear=2012, puMonth=3),
#  Row(vendorID='VTS', tpepPickupDateTime=datetime.datetime(2012, 2, 29, 23, 52), tpepDropoffDateTime=datetime.datetime(2012, 3, 1, 0, 10), passengerCount=3, tripDistance=6.04, puLocationId=None, doLocationId=None, startLon=-73.986568, startLat=40.740285, endLon=-73.965988, endLat=40.80799, rateCodeId=1, storeAndFwdFlag=None, paymentType='CRD', fareAmount=15.7, extra=0.5, mtaTax=0.5, improvementSurcharge=None, tipAmount=1.3, tollsAmount=0.0, totalAmount=18.0, puYear=2012, puMonth=3),
#  Row(vendorID='VTS', tpepPickupDateTime=datetime.datetime(2012, 3, 6, 0, 5), tpepDropoffDateTime=datetime.datetime(2012, 3, 6, 0, 19), passengerCount=1, tripDistance=3.95, puLocationId=None, doLocationId=None, startLon=-73.964092, startLat=40.808045, endLon=-73.995732, endLat=40.759855, rateCodeId=1, storeAndFwdFlag=None, paymentType='CRD', fareAmount=12.1, extra=0.5, mtaTax=0.5, improvementSurcharge=None, tipAmount=2.52, tollsAmount=0.0, totalAmount=15.62, puYear=2012, puMonth=3),
#  Row(vendorID='VTS', tpepPickupDateTime=datetime.datetime(2012, 2, 29, 23, 53), tpepDropoffDateTime=datetime.datetime(2012, 3, 1, 0, 17), passengerCount=1, tripDistance=12.11, puLocationId=None, doLocationId=None, startLon=-74.002562, startLat=40.739575, endLon=-73.837808, endLat=40.725213, rateCodeId=1, storeAndFwdFlag=None, paymentType='CRD', fareAmount=27.7, extra=0.5, mtaTax=0.5, improvementSurcharge=None, tipAmount=5.64, tollsAmount=4.8, totalAmount=39.14, puYear=2012, puMonth=3),
#  Row(vendorID='CMT', tpepPickupDateTime=datetime.datetime(2012, 3, 3, 21, 8, 59), tpepDropoffDateTime=datetime.datetime(2012, 3, 3, 21, 13, 37), passengerCount=2, tripDistance=1.6, puLocationId=None, doLocationId=None, startLon=-73.975462, startLat=40.741095, endLon=-73.959687, endLat=40.757823, rateCodeId=1, storeAndFwdFlag='N', paymentType='CSH', fareAmount=5.7, extra=0.5, mtaTax=0.5, improvementSurcharge=None, tipAmount=0.0, tollsAmount=0.0, totalAmount=6.7, puYear=2012, puMonth=3),
#  Row(vendorID='VTS', tpepPickupDateTime=datetime.datetime(2012, 2, 29, 23, 56), tpepDropoffDateTime=datetime.datetime(2012, 3, 1, 0, 6), passengerCount=1, tripDistance=3.04, puLocationId=None, doLocationId=None, startLon=-74.003192, startLat=40.732747, endLon=-73.997727, endLat=40.765165, rateCodeId=1, storeAndFwdFlag=None, paymentType='CSH', fareAmount=10.1, extra=0.5, mtaTax=0.5, improvementSurcharge=None, tipAmount=0.0, tollsAmount=0.0, totalAmount=11.1, puYear=2012, puMonth=3),
#  Row(vendorID='VTS', tpepPickupDateTime=datetime.datetime(2012, 3, 11, 14, 42), tpepDropoffDateTime=datetime.datetime(2012, 3, 11, 14, 49), passengerCount=1, tripDistance=1.34, puLocationId=None, doLocationId=None, startLon=0.0, startLat=0.0, endLon=0.0, endLat=0.0, rateCodeId=1, storeAndFwdFlag=None, paymentType='CSH', fareAmount=6.1, extra=0.0, mtaTax=0.5, improvementSurcharge=None, tipAmount=0.0, tollsAmount=0.0, totalAmount=6.6, puYear=2012, puMonth=3),
#  Row(vendorID='VTS', tpepPickupDateTime=datetime.datetime(2012, 2, 29, 23, 57), tpepDropoffDateTime=datetime.datetime(2012, 3, 1, 0, 1), passengerCount=1, tripDistance=1.05, puLocationId=None, doLocationId=None, startLon=-73.992645, startLat=40.743107, endLon=-73.984735, endLat=40.755035, rateCodeId=1, storeAndFwdFlag=None, paymentType='CSH', fareAmount=4.9, extra=0.5, mtaTax=0.5, improvementSurcharge=None, tipAmount=0.0, tollsAmount=0.0, totalAmount=5.9, puYear=2012, puMonth=3),
#  Row(vendorID='VTS', tpepPickupDateTime=datetime.datetime(2012, 3, 18, 21, 40), tpepDropoffDateTime=datetime.datetime(2012, 3, 18, 21, 46), passengerCount=1, tripDistance=0.77, puLocationId=None, doLocationId=None, startLon=-73.991392, startLat=40.726062, endLon=-73.980863, endLat=40.725678, rateCodeId=1, storeAndFwdFlag=None, paymentType='CRD', fareAmount=4.9, extra=0.5, mtaTax=0.5, improvementSurcharge=None, tipAmount=1.0, tollsAmount=0.0, totalAmount=6.9, puYear=2012, puMonth=3),
#  Row(vendorID='VTS', tpepPickupDateTime=datetime.datetime(2012, 2, 29, 23, 56), tpepDropoffDateTime=datetime.datetime(2012, 3, 1, 0, 13), passengerCount=1, tripDistance=3.73, puLocationId=None, doLocationId=None, startLon=-73.985187, startLat=40.74779, endLon=-74.00736, endLat=40.70928, rateCodeId=1, storeAndFwdFlag=None, paymentType='CRD', fareAmount=12.1, extra=0.5, mtaTax=0.5, improvementSurcharge=None, tipAmount=2.52, tollsAmount=0.0, totalAmount=15.62, puYear=2012, puMonth=3),
#  Row(vendorID='VTS', tpepPickupDateTime=datetime.datetime(2012, 3, 2, 23, 15), tpepDropoffDateTime=datetime.datetime(2012, 3, 2, 23, 37), passengerCount=2, tripDistance=3.25, puLocationId=None, doLocationId=None, startLon=-73.984268, startLat=40.725032, endLon=-73.986507, endLat=40.758658, rateCodeId=1, storeAndFwdFlag=None, paymentType='CSH', fareAmount=13.3, extra=0.5, mtaTax=0.5, improvementSurcharge=None, tipAmount=0.0, tollsAmount=0.0, totalAmount=14.3, puYear=2012, puMonth=3)]
